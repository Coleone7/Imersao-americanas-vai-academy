# %% [markdown]
# # <center>VAI Academy</center>
# # <center> Introdução à Python e Pandas - Parte 2 </center>
# ___
# Todo o conteúdo que você terá acesso ao longo desse período é confidencial, não sendo possível compartilhar ou comercializar os links ou os materiais recebidos que sejam de propriedade da VAI Academy.
#
# Dessa forma, ao participar do curso você está aceitando os termos de confidencialidade e não-comercialização dos conteúdos que serão recebidos.
# ___
#
# # <center> Objetivos de aprendizado </center>
# - Familiarizar-se com o Jupyter Notebook
# - Ser capaz de interpretar e escrever um código básico em Python
# - Conhecer os tipos de dados do Python
# ___
#
# ## Conteúdo
# 1. Introdução (Parte 1)
# 2. [Python/Jupyter Básico (Partes 1 e 2)](#basics)
# 3. Python Datatypes (Parte 3)
# 4. Funções (Parte 4)
# 5. Numpy (Parte 5)
# 6. Pandas (Partes 6 e 7)

# %% [markdown]
# <a name="basics"></a>
# ### 2.7. Variáveis e Tipos
#
# Em Python, uma variável nada mais é que um **label**, um nome. Considere que uma variável seja um nome atrelado a um objeto, mas **não é o próprio objeto!** No Python, não é necessário realizar declaração de variáveis (como é necessário em muitas outras linguagens de programação). A variável é criada no momento que você atribui um valor a ela. **Assignment (atribuição de valor)** é feita com sinal de igual simples (=):

# %%
# Criando uma variável x ao atribuir um valor a ela

x = 5 # Lê-se como algo do tipo “a x é atribuído o valor 5".

# Uma vez que a atribuição é feita, a variável poderá ser usada em qualquer expressão, e seu valor poderá ser substituído
print(x)
# Out:
# 5

# %% [markdown]
# ![Imgur](https://i.imgur.com/I3KOq2E.jpg).

# %% [markdown]
# #### 2.7.1. Nomes de variáveis
# Uma variável pode ter um nome curto (como x ou y) ou um nome mais descritivo (idade, nome_carro, volume_total). [Regras para nomes de variáveis](https://www.python.org/dev/peps/pep-0008/#function-and-variable-names) no Python podem ser sintetizadas da seguinte forma:
# - Um nome de variável deve começar com uma letra ou o caractere underscore
# - Um nome de variável não pode começar com um algarismo numérico
# - Um nome de variável deve conter apenas caracteres alfanuméricos e underscores (A-z, 0-9, and _ )
# - Nomes de variáveis são case-sensitives (age, Age e AGE são três variáveis distintas)

# %%
# Criando três variáveis utilizando as convenções de nomes
name = "Jose da Silva"
age  = 27
likes_python = True

# Printando as variáveis
print ("Nome: ", name)
print ("Idade:  ", age)
print ("Gosta de Python? ", likes_python)
# Out:
# Nome:  Jose da Silva
# Idade:   27
# Gosta de Python?  True

# %% [markdown]
# #### 2.7.2. Cálculos com variáveis
# Agora que já sabemos como criar variáveis com "bons nomes", nós podemos usá-las para fazer alguns cálculos. Vamos resolver o exercício 2.3, mas, agora, utilizando variáveis em vez de printar o resultado diretamente.

# %%
# Crie a variável que represente o capital inicial
savings = 100

# Crie a variável growth_multiplier
growth_multiplier = 1.1

# Crie a variável que contenha o período de investimento (em anos)
time_investing = 25

# Calcule o resultado
result = savings * growth_multiplier ** time_investing

# Printe o resultado
print("O montante acumulado por", name, "ao longo de", time_investing, "anos foi de", result, "reais!")
# Out:
# O montante acumulado por Jose da Silva ao longo de 25 anos foi de 1083.4705943388394 reais!

# %% [markdown]
# #### 2.7.3. Outros Tipos de Variáveis
# Nas seções anteriores, nós lidamos com números inteiros, números não-inteiros e strings (textos). Esses são alguns de muitos [tipos de dados do Python](https://docs.python.org/3/library/datatypes.html), mas existem quatro principais tipos de dados:
#
# - **int**: números inteiros. Ex: 0, 100, -3, etc;
# - **float**: um número que possui tanto uma parte inteira quanto uma parte fracionária, separada por uma casa decimal (representada por um ponto .). Ex: 0.5, 0.33, -0.1, etc;
# - **str**: também chamada de string, é um tipo que representa texto. Você pode utilizar tanto aspas simples quantos aspas duplas para construir uma string. Ex: "Hi", 'Hello'
# - **bool**: representa valores lógicos e só pode assumir dois valores, *True* ou *False*.

# %%
# Integer (int)
integer_number = 1

# Floating point (float)
float_number = 1.0

# String (str)
text = "Hello"

# Boolean (bool)
python_is_fun = True

# %% [markdown]
# Para descobrir o tipo de um valor ou da variável que se refere àquele valor, você pode usar a função type()!

# %%
# Variable types
print(type(integer_number))
print(type(float_number))
print(type(text))
print(type(python_is_fun))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# Mas como o Python assimila o tipo de uma variável? Bem, ele infere a partir do valor atribuído àquela variável. Essas linguagens de programação são conhecidas como [loosely typed programming languages](https://en.wikipedia.org/wiki/Strong_and_weak_typing).

# %% [markdown]
# #### 2.7.4. Operações com outros Tipos
# Como nós já falamos, existem vários tipos de operação que você pode fazer. Em Python, o tipo do operando afeta os outputs das operações e suas viabilidades! Vamos tentar algumas combinações diferentes!

# %%
# Adição
print(True + False) #(1 + 0)
print ("O nome do meu amigo é " + "João") #(string + string)
print(True + 100) # (1+100) 
print(100 + 9.9)
# Out:
# 1
# O nome do meu amigo é João
# 101
# 109.9

# %%
# Multiplicação
print(True * True) # (1*1)
print(101 * False) #(101 * 0) = 0
print("Tuntz " * 10) #repetir a string 10x.
print("Hi" * (True+True)) #true = 1 , portanto, string * (1+1) = 2*string
# Out:
# 1
# 0
# Tuntz Tuntz Tuntz Tuntz Tuntz Tuntz Tuntz Tuntz Tuntz Tuntz
# HiHi

# %%
# Exponenciação
print(True**9999) #(1^9999) = 1
print(100 ** False)  #( 100 ^ 0) = 1
# Out:
# 1
# 1

# %% [markdown]
# #### Exercício 2.7
#
# Guarde na variável ```resultado_2_7``` (substituindo o ```____```) o resultado de uma adição que não utiliza nenhum integer ou float, porém retorne um número inteiro.

# %%
# Sua resposta aqui
resposta_2_7 = (True + True)
print(resposta_2_7)
# Out:
# 2

# %% [markdown]
# #### 2.7.5. Conversão de Tipo
# Se você tentou fazer diferentes combinações no exercício anterior, você deve ter visto alguns erros, mas não tem problema!
# Vamos observar o código abaixo (apenas tenha certeza que você já atribuiu os valores dessas variáveis neste notebook)!

# %%
# Printe com erro
print("Eu comecei com $" + savings + " e agora eu tenho $" + result + ". Ótimo!!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-8b8c49f1c86c> in <module>()
#       1 # Printe com erro
# ----> 2 print("Eu comecei com $" + savings + " e agora eu tenho $" + result + ". Ótimo!!")
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# No exemplo acima, se você olhar para a mensagem de erro, verá que foi um *TypeError*. Nós não vamos entrar nesses detalhes agora, mas você pode assumir que esse erro é causado pelo tipo de uma ou mais variáveis/valores que tentamos printar. Neste caso, nós tentamos adicionar uma string a um número e isso não é permitido nas regras da sintaxe do Python. Seria maneiro se fosse possível fazer isso, não seria?
#
# Para consertar esse erro, nós precisamos explicitamente converter os tipos das variáveis. Mais especificamente, nós precisaremos da função [str()](https://docs.python.org/3/library/functions.html#func-str) para converter um valor para uma string. *str(savings)*, por exemplo, vai converter o float *savings* para uma string.

# %%
# print correto
print("Eu comecei com $" + str(savings) + " e agora eu tenho $" + str(result) + ". Ótimo!!")
# Out:
# Eu comecei com $100 e agora eu tenho $1083.4705943388394. Ótimo!!

# %% [markdown]
# Outras funções de conversão de tipo:
# [int()](https://docs.python.org/3/library/functions.html#int), [float()](https://docs.python.org/3/library/functions.html#float) e [bool()](https://docs.python.org/3/library/functions.html#bool) vão ajudar você a converter valores para qualquer tipo!

# %%
# Atribuição de variáveis
integer = 1
float_number = 3.1415
string = "3"
boolean = True

#str
print("--------str()---------")
print("O integer é agora um string! Veja: " + str(integer))
print("O float é agora um string! Veja: " + str(float_number))
print("O boolean é agora um string! Veja: " + str(boolean))

print("--------int()---------")
#int
print("O float é agora um integer! Veja: ", int(float_number)) #Você pode dizer por que não podemos usar "+" aqui? --- Não é possivel somar numeros com strings.
print("O boolean é agora um integer! Veja: ", int(boolean))    #Isso será explicado na seção de funções            --- Ou você soma numeros ou concatena strings.
print("O string é agora um integer! Veja: ", int(string))

print("--------float()---------")
#float
print("O integer é agora um float! Veja: ", float(integer))
print("O string é agora um float! Veja: ", float(string))
print("O boolean é agora um float! Veja: ", float(boolean))

print("--------bool()---------")
#bool
print("O integer é agora um boolean! Veja: ", bool(integer))
print("O float é agora um boolean! Veja: ", bool(float_number))
print("O string é agora um boolean! Veja: ", bool(string))
# Out:
# --------str()---------
# O integer é agora um string! Veja: 1
# O float é agora um string! Veja: 3.1415
# O boolean é agora um string! Veja: True
# --------int()---------
# O float é agora um integer! Veja:  3
# O boolean é agora um integer! Veja:  1
# O string é agora um integer! Veja:  3
# --------float()---------
# O integer é agora um float! Veja:  1.0
# O string é agora um float! Veja:  3.0
# O boolean é agora um float! Veja:  1.0
# --------bool()---------
# O integer é agora um boolean! Veja:  True
# O float é agora um boolean! Veja:  True
# O string é agora um boolean! Veja:  True

# %% [markdown]
# #### Exercício 2.8
#
# Printe uma mensagem simples utilizando todos os tipos de variáveis do exemplo acima:

# %%
# Variáveis
integer = 1
float_number = 3.1415
string = "3"
boolean = True

# Printe uma mensagem simples usando as quatro variáveis atribuídas acima
print (
    "O valor", 
    int(integer),"é um número inteiro assim como",
    float(float_number), "é um número real.",
    str(string), "é um texto, que poderiamos escrever como 'Três', e",
    bool(boolean), "indica um valor lógico."    
    )
# Out:
# O valor 1 é um número inteiro assim como 3.1415 é um número real. 3 é um texto, que poderiamos escrever como 'Três', e True indica um valor lógico.

# %% [markdown]
# ### 2.8. Estruturas de decisão
# Até agora, todos os exemplos seguiram um fluxo contínuo, onde todas as linhas de código de uma mesma célula foram executadas. Entretanto, em aplicações reais, isso raramente é o que acontece e, nesses casos, nós temos que usar o que chamamos de **estruturas de decisão** para redirecionar o fluxo de execução baseado em critérios condicionais que guiam o programa. Para fazer isso no Python, nós usamos **if**, **else** e **elif** statements, que possuem a seguinte estrutura genérica:

# %%
# if(condição lógica 1 ):
#    executa esse bloco de código se a condição lógica 1 for verdadeira
#    bloco de código
#    bloco de código
# elif(condição lógica 2):
#    executa esse bloco de código se a condição lógica 2 for verdadeira
#    bloco de código
#    bloco de código
# elif(condição lógica 3):
#    executa esse bloco de código se a condição lógica 3 for verdadeira
#    bloco de código
#    bloco de código
#         .
#         .
#         .
# else:
#    executa esse bloco de código se nenhuma das condições lógicas anteriores forem verdadeiras
#    bloco de código
#    bloco de código

# %% [markdown]
# Antes que continuemos, é importante observar que, no Python, não existe nenhum caractere que indique um bloco de código, como há em muitas outras linguagens de programação (comumente o ;). Na verdade, o que o Python considera como o início de um novo bloco de código está baseado apenas na **indentação/tabulação** do código!!! **Isso é muito importante para o Python! Preste sempre atenção na indentação dos seus scripts, pois um tab a mais (ou a menos) pode mudar toda a lógica do seu código!** No mundo dos negócios, não queremos que um erro causado por isso gere um resultado catrastrófico, não é mesmo?
#
# Observe a seguinte imagem e exemplo abaixo:
# ![Identation](https://i.imgur.com/qQ6zBHk.png)

# %%
# Programa que diz se um aluno vai passar na disciplina, dada a sua nota final
grade = 6 # Nota final do aluno

# Estrutura de decisão/lógica
if (grade >= 7):
    print("Aprovado!")
elif ((grade < 7) & (grade >= 5)):
    print("Recuperação")
else:
    print("Reprovado!")
# Out:
# Recuperação

# %% [markdown]
# #### Exercício 2.9
#
# Baseado no exemplo acima e sabendo que a nota final deve ser maior que 7 **e** a presença nas aulas deve ser maior que 70% para um aluno ser aprovado diretamente, e que para um aluno ter direito a recuperação, é necessário que sua nota seja maior ou igual a 5 **e** sua presença seja ao menos 50%, modifique o código abaixo para que ele leve em conta a condição de presença de aulas do aluno. Não se esqueça de printar o resultado!

# %%
# Programa que diz se um aluno vai passar na disciplina, dada a sua nota final
grade = 6 # Nota final do aluno
attendance = 51

# Estrutura de decisão/lógica
if ((grade >= 7) & (attendance >= 70)):
    print("Aprovado!")
elif ((grade < 7) & (grade >= 5) & (attendance >= 50)):
    print("Recuperação")
else:
    print("Reprovado!")
# Out:
# Recuperação

# %% [markdown]
# ### 2.9. Estruturas de laço (Looping structures)
#
# Na seção anterior, introduzimos o conceito em que você pode determinar quais blocos de código serão executados baseado em critérios condicionais. Entretanto, em muitas ocasiões, queremos continuar fazendo esses testes condicionais para ver se o sistema está mudando com o tempo. Existem, então, dois tipos de estruturas de laço: o ```while``` e o ```for```.
#
# #### 2.9.1. **While**
#
# O comando while continua em loop enquanto a condição de teste continua retornando True.

# %%
# Variável contadora
counter = 1

# While loop
while counter <= 3: # Testa se counter <= 3. Se True, executa o bloco de código. Caso contrário, sai do loop
    print(counter)
    counter = counter + 1
# Out:
# 1
# 2
# 3

# %% [markdown]
# #### 2.9.2. For
# Esse comando executa o loop por um determinado número de vezes. Normalmente, utiliza-se a função **range** para determinar quantos loops serão executados.

# %%
# range(start, stop)
selected_range = range(1,4)
print("Selected range = ", *selected_range) # O operador * "desempacota" a sequência previamente definida

# For loop
for counter in selected_range:
    print(counter)
# Out:
# Selected range =  1 2 3
# 1
# 2
# 3

# %% [markdown]
# #### 2.9.3. Interruptions
# É possível interromper a execução de um loop com os seguintes comandos:
# - **break**: cancela o loop
# - **continue** : recomeça o loop a partir do próximo contador

# %%
# For loop
for counter in range(1,11):
    if counter == 7:
        break; # Para o looping quando counter == 7
    print(counter)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
# For loop
for counter in range(1,11):
    if counter == 7:
        continue; # Pula o loop quando counter == 7
    print(counter)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 8
# 9
# 10

# %% [markdown]
# #### Exercício 2.10
#
# Baseado no que você acabou de aprender, crie a string ```resultado_2_7``` com apenas os números múltiplos de 100 entre 1 e 1000 (inclusive) utilizando a função ```range```.

# %%
# Escreva sua resposta aqui
resposta_2_10 = 'resposta'

for counter in range (1,1001):
    if counter % 100 == 0:
        resposta_2_10 = resposta_2_10 + ',' + str(counter)
    else:
        None
print(resposta_2_10)
# Out:
# resposta,100,200,300,400,500,600,700,800,900,1000

# %% [markdown]
# #### 2.9.4. Try Except
#
# Até o momento, as mensagens de erro foram apenas mencionadas e você provavelmente recebeu algumas ao tentar fazer os exercícios propostos. Agora que você já sabe sobre as estruturas de laço, podemos aprender a lidar com as mensagens de erros, que podem ser basicamente de dois tipos: *syntax erros* e *exceptions*.
#
# Os **syntax erros** (erros de sintaxe) também são conhecidos como *parsing errors* e correspondem aos erros mais comuns que você vai receber enquanto aprende Python. Observe um exemplo abaixo.

# %%
# Print com erro de sintaxe
while counter <= 3:
    print(counter)
    counter = counter + 1

# %% [markdown]
# Observe que a linha com o erro é indicada, e há uma pequena seta apontando ao ponto em que o erro foi detectado, de forma que podemos rapidamente identificar onde está o problema e resolvê-lo. Neste exemplo, o erro acontece pois está faltando o ```:``` antes do bloco de código a ser executado.
#
# Mesmo que a sintaxe do seu código esteja correta, pode ocorrer um erro quando você tenta executá-lo. Esses erros durante a execução são chamados de **exceptions** e vamos te mostrar uma forma de lidar com eles no Python. Observe os exemplos de *exception* abaixo.

# %%
print(10 * (1/0))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-28-9500656ba1ce> in <module>()
# ----> 1 print(10 * (1/0))
#
# ZeroDivisionError: division by zero

# %%
print(4 + numero_armazenado*5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-c87223de0173> in <module>()
# ----> 1 print(4 + numero_armazenado*5)
#
# NameError: name 'numero_armazenado' is not defined

# %%
print('5' + 7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-631499865ea0> in <module>()
# ----> 1 print('5' + 7)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# Observe que a última linha do erro indica o que aconteceu. As *exceptions* podem ser de diferentes tipos, o qual é printado como parte da mensagem. Nestes exemplos, os tipos são: *ZeroDivisionError*, *NameError* e *TypeError*.
#
# Para lidar com as exceções, podemos utilizar o statement *try* dentro de um loop. O exemplo abaixo pede que o usuário insira um número, e realiza um loop até que o número inserido seja um inteiro.

# %%
while True:
    try:
        x = int(input("Please enter a number: "))
        break
    except ValueError:
        print("Oops!  That was no valid number.  Try again...")
# Out:
# Please enter a number: 10

# %% [markdown]
# No exemplo citado, o statement *try* funciona da seguinte maneira: primeiro, o bloco de código dentro do *try* é executado (solicitando um número), e, caso não ocorra uma *exception*, seu bloco é pulado e a execução do *try* é finalizada (e o loop do while é interrompido pelo *break*, cujo funcionamento será explicado na seção seguinte).
#
# Caso uma *exception* ocorra (com a inserção de um caractere não numérico), o resto do bloco do *try* é ignorado e o bloco do *except* é executado (mostrando a mensagem de que não foi inserido um número válido).

# %% [markdown]
# Mas **atenção**! Tome muito cuidado ao utilizar o try except, pois você pode criar um **loop infinito**, que só é interrompido ao reiniciar o kernel do notebook (perdendo todas as variáveis criadas e dados carregados). Isso pode ocorrer pois a interrupção do kernel durante a execução de uma célula gera uma *exception*, e caso não especifiquemos a *exception* a ser tratada, podemos fazer com que o *try* seja executado repetidamente. Observe abaixo a alteração realizada no exemplo anterior:
#
# while True: <br>
# &nbsp;&nbsp;&nbsp;&nbsp;try: <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;x = int(input("Please enter a number: ")) <br>
# &nbsp;&nbsp;&nbsp;&nbsp;except: <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;print("Oops!  That was no valid number.  Try again...") <br>
#
# Se executássemos uma célula com esse código, por mais que digitássemos um número válido, o loop do while continuaria (visto que não há uma interrupção, como um *break*). Além disso, se digitássemos um caractere não numérico ou tentássemos interromper a execução da célula, teríamos uma *exception*, porém a ocorrência da mesma executa apenas um print informando para o usuário tentar novamente e em seguida retorna à execução do *try*. Dessa forma, o loop só pode ser interrompido se o kernel for reiniciado. Por isso, sempre utilize um *break* no seu loop ou especifique a *exception* a ser tratada.

# %% [markdown]
# # Declaração de Inexistência de Plágio:
#
# 1. Eu sei que plágio é utilizar o trabalho de outra pessoa e apresentar como meu.
# 2. Eu sei que plágio é errado e declaro que este notebook foi feito por mim.
# 3. Tenho consciência de que a utilização do trabalho de terceiros é antiético e está sujeito à medidas administrativas.
# 4. Declaro também que não compartilhei e não compartilharei meu trabalho com o intuito de que seja copiado e submetido por outra pessoa.

# %%
# LEMBRE-SE DE SALVAR O NOTEBOOK ANTES DE EXECUTAR ESSA CELULA
token = 'b193b438-0c93-4e14-b5db-fb21f6e2331e' # seu token aqui

# Não altere o código abaixo
import requests as req
exec(req.get('https://api.vai.academy/submissioncode2').text)
# Out:
# Importante: lembre-se de salvar o notebook antes de rodar esta célula!
# Executando o seu notebook para a submissão. Isso pode demorar alguns instantes...
# >> Verificando exercicios para correção...
# >> Submetendo exercício 2.7... "Score: 1/1"
# >> Submetendo exercício 2.10... "Score: 2/2"
#
# Tentativa de submissao #1 / 30
# Aluno: Murilo Coleone
# Score: 3 / 3
# Parabéns!! Você atingiu os critérios para passar neste notebook.
#
# Pontuação por exercício
# Exercicio  Pontuacao Maxima  Pontuacao Obtida
#       2.7                 1                 1
#      2.10                 2                 2

# %% [markdown]
# ## Fim da primeira parte da aula!

# %% [markdown]
# Parabéns por finalizar o notebook! Agora você já sabe o básico de Python e pode prosseguir para a segunda parte, onde você vai aprender a criar suas próprias funções, como no exemplo acima!
